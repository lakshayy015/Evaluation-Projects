# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import norm
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# This dataset contains the details of the team in which numerical data are present. Here "wins" is the target variable which contains the numerical data so it will be termed as "Numerical Problem" where we need to predict the several wins using the Numerical models.

# %%
df.head(10)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5  93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6  87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7  81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8  80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9  78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86
# 5  34   88
# 6  48   93
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# This dataset contain 30 rows and 17 columns. Out of which 1 is target variable and remaining 16 columns are independent variables.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# There are two different types of data (int64,flot64) present in the dataset.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# There is no null value in this dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# This gives the brief about the dataset which includes indexing type, Column type no null values and memory usage.

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# And we can clearly visulize that there is no missing data present.

# %%
#Checking the value counts of each column 
for i in df.columns:
    print (df[i].value_counts())
    print("\n")
# Out:
# W
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: count, dtype: int64
#
#
# R
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: count, dtype: int64
#
#
# AB
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %% [markdown]
# These are the value counts of all columns and we can see in some columns are repeated value like 'W','R','AB','H','2B','3B','HR','BB','SO','SB','CG','SHO','SV'and'E'.

# %%
#Separating Numerical and Categorical columns

#Checking for catagorical columns 
categorical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print ("Categorical Columns:", categorical_col)
print ("\n")

#Checking for Numerical Columns
numerical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print ("Numerical Columns:", numerical_col)
# Out:
# Categorical Columns: []
#
#
# Numerical Columns: ['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'E']

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#      No. of unique values
# W                      24
# R                      28
# AB                     29
# H                      29
# 2B                     22
# 3B                     23
# HR                     27
# BB                     29
# SO                     29
# SB                     27
# RA                     30
# ER                     30
# ERA                    30
# CG                      9
# SHO                    12
# SV                     20
# E                      21

# %% [markdown]
# These are the unique values in the dataset. Here 'RA','ER'and 'ERA'columns has the data total values are unique.

# %%
#Checking the list of counts of target
df["W"].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# These are the 24 unique values are persent in the target column.

# %%
#Checking the unique values in target column
df['W'].value_counts()
# Out:
# W
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# This gives the statistical information of the numerical columns. The summary of the dataset looks perfect since there is no negative vlaues present.
#
# From the above description I can observe the following:-
# 1) The counts of all the columns are same which means there are no missing values in the dataset.
# 2) The mean value is greater than the median (50%) in 'AB','H','3B','HR','SV'and'E'columns which means the data is skewed to right in these column.
# 3) The mean value is less than the median (50%) in 'W'.'R','2B','BB','SO','RA','ER','ERA','CG'and'SHO'columns which the data is skewed to left in these column.
# 4) The mean value is equal to the median value in one column i.e.'SB'.
# 5) By summarizing the data we can observe there is a huge difference between 75% and max hence there are present int he data.
# 6) We can also notice the standard deviation, min, 25% percentile values from this describe method.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Univariate Analysis

# %%
#Let's check how the data has been distributed in remaining coulumn 
plt.figure(figsize=(10,6), facecolor = "White")
plotnumber = 1
for col in numerical_col:
    if plotnumber<=17:
        sns.displot(df[col], color = "m")
        plt.xlabel(col, fontsize = 12)
        plt.yticks(rotation = 0, fontsize = 10)
    plotnumber+=1 
plt.tight_layout()

# %% [markdown]
# From the above distribution plots we can notice that the data almost looks normal in all the columns.

# %% [markdown]
# Bivarite Analysis

# %%
#Compering
